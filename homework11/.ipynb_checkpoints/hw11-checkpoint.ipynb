# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.
# Maria Dubiel

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
def calculate_orbital_period(a):
    """
    This function will calculate orbital period in years given the semi-major axis(a) in AU.
    """
    period = (a**3) ** 0.5
    return period

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
planet_a = 0.5
planet_b = 1
planet_c = 1.5

print(calculate_orbital_period(planet_a))
print(calculate_orbital_period(planet_b))
print(calculate_orbital_period(planet_c))
# Out:
# 0.3535533905932738
# 1.0
# 1.8371173070873836

# %% [markdown]
# Import `numpy` in the cell below.

# %%
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# You only need to call numpy once in a jupyter notebook. This is becuase after its imported it will work in all of the followig lines of code.

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
def orbital_period(a):
    """
    This function will calculate orbital period in years given the semi-major axis(a) in AU.
    """
    period = np.sqrt(a**3)
    return period

# %% [markdown]
# Import the `time` package in the cell below.

# %%
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
start = time.perf_counter()
calculate_orbital_period(5)
end = time.perf_counter()
print(end - start)
# Out:
# 9.020000288728625e-05

# %%
start_2 = time.perf_counter()
orbital_period(5)
end_2 = time.perf_counter()
print(end_2 - start_2)
# Out:
# 6.940000457689166e-05

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# The function that uses numpy is faster. This is likely becuase the numpy function improves the efficiency of the code.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1,000,000 semi-major axis values.

# %%
semimajor_axis_values = np.linspace(0.1, 50, 1000000)

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
start_1 = time.perf_counter()
for i in semimajor_axis_values:
    period = calculate_orbital_period(i)
end_1 = time.perf_counter()
print(end_1 - start_1)
# Out:
# 0.5508214000001317

# %%
start_2 = time.perf_counter()
for i in semimajor_axis_values:
    period = orbital_period(i)
end_2 = time.perf_counter()
print(end_2 - start_2)
# Out:
# 1.6456609000015305

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
#The first function was much faster. This may be becuase it did not have a numpy fucntion. 
#This would suggest that numpy functions may not always be the most efficient in every scenario

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

def find_planets(temperatures, radii):
    """
    Will filter and print the radii of planets with temperatures below 350 K
    """
    filtered_radii = []
    for i in range(len(temperatures)):
        if temperatures[i] < 350:
            filtered_radii.append(radii[i])
    return filtered_radii

find_planets(temperatures, radii)
# Out:
# [1.2, 2.0]

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
print(radii[0: 3: 1])
# Out:
# [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
rad_temp_pairs = [[1.2, 300],[0.8, 400],[1.5, 350], [2.0, 280], [1, 500], [0.6, 450]]
radii_and_temperatures = dict(rad_temp_pairs)
print(radii_and_temperatures)
# Out:
# {1.2: 300, 0.8: 400, 1.5: 350, 2.0: 280, 1.0: 500, 0.6: 450}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
keys = ["Planet 1", "Planet 2", "Planet 3", "Planet 4", "Planet 5", "Planet 6"]
planet_radii_and_temperatures = dict(zip(keys, rad_temp_pairs))
print(planet_radii_and_temperatures)
# Out:
# {'Planet 1': [1.2, 300], 'Planet 2': [0.8, 400], 'Planet 3': [1.5, 350], 'Planet 4': [2.0, 280], 'Planet 5': [1, 500], 'Planet 6': [0.6, 450]}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
planet_rad_and_temps = {"Planet 1": {"radius":1.2, "temperature":300}, "Planet 2": {"radius":0.8, "temperature": 400}, "Planet 3": {"radius":1.5, "temperature":350}, "Planet 4": {"radius": 2.0, "temperature": 280}, "Planet 5": {"radius": 1, "temperature": 500}, "Planet 6": {"radius":0.6, "temperature":450}}
new_list_planets = {} #new dictionary we'll be adding things to
for key, data in planet_rad_and_temps.items():
    if 1.0 <= data["radius"]<= 2.0:
        new_list_planets[key] = data

print(new_list_planets)
# Out:
# {'Planet 1': {'radius': 1.2, 'temperature': 300}, 'Planet 3': {'radius': 1.5, 'temperature': 350}, 'Planet 4': {'radius': 2.0, 'temperature': 280}, 'Planet 5': {'radius': 1, 'temperature': 500}}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
semimajor_axis_array = np.array(semimajor_axis_values)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
average = np.mean(semimajor_axis_array)
median = np.median(semimajor_axis_array)
minimum = np.min(semimajor_axis_array)
maximum = np.max(semimajor_axis_array)
print(f"average: {average}, median: {median}, minimum: {minimum}, maximum: {maximum}")
# Out:
# average: 25.050000000000004, median: 25.05, minimum: 0.1, maximum: 50.0

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
standard_deviation = np.std(semimajor_axis_array) #calculates the standard deviation of the elements in the array
print(standard_deviation)
# Out:
# 14.404903621177585

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
radii_and_temps = np.array([radii, temperatures])

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
for r, row in enumerate(radii_and_temps):
    if r == 1:
        for t, element in enumerate(row):
            if t == 2:
                print(element)
# Out:
# 350.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
print(radii_and_temps[1,2])
# Out:
# 350.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
#NOTE: My kernel  keeps dying whenever I try to run this code, I'm not sure what's causing it.
# I've written the code out but I can't run it, so I'll leave it without the plots.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

# %%
semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
a = np.array(semi_major_axes)

# %%
orbital_periods = (a**3)**0.5

# %%
plt.figure(figsize=(3,3))
plt.title("Orbital Periods of Exoplanets")
plt.xlabel("Semi-Major Axis (AU)")
plt.ylabel("Orbital Period (years)")
plt.scatter(a, orbital_periods, label = "Data", color = "pink")
plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

plt.figure(figsize=(3,3))
plt.title("Equilibrium Temperatures vs. Radii")
plt.xlabel("Semi-Major Axis (AU)")
plt.ylabel("Temperature (Kelvin)")
plt.bar(radii, temperatures, color = "red")
plt.show()

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
fig, ax = plt.subplots(1, 2, figsize=(6,6))
    ax[0].plot(a, orbital_periods, color = "pink")
    ax[1].plot(r, T, color = "red")
    for i, ax in enumerate(ax.flat):
        ax.set_title(f"Frame {i}")
        print(i)
    plt.show
# Out:
#   Cell In[4], line 2
#     ax[0,0].plot(a, orbital_periods, color = "pink")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
import orbital_period as op

# %%
op.orbital_period(9)
# Out:
# 27.0
